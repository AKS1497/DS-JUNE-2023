# %% [markdown]
# > FUNCTIONS, FILTERS AND LAMBDA EXPRESSIONS
# >
# > ( practice questions )
# >
# > QUES 1:- WRITE A FUNCTION THAT TAKES A VARIABLE AND SQUARE IT, THEN
# > TEST THE FUNCTION BY TAKING AN INPUT FROM A USER
#
# <table>
# <colgroup>
# <col style="width: 50%" />
# <col style="width: 50%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><p>In [3]:</p>
# <p>In [4]:</p></th>
# <th><table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p><strong>def</strong> square_test():<br />
# n<strong>=</strong> int(input("Enter number:- "))<br />
# square <strong>=</strong> n<strong>**</strong>2<br />
# print(f"Square of {n} is {square}")</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
# <table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>square_test()</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
#
# > Enter number:- 5
# > Square of 5 is 25
# >
# > QUES 2:- WRITE A FUNCTION THAT TAKES 2 VARIABLE AND OBTAIN THE
# > SUMMATION AND MULTIPLICATION, THEN TEST THE FUNCTION BY TAKING AN
# > INPUT FROM A USER (REPEAT USING LAMBDA EXPRESSIONS)
#
# <table>
# <colgroup>
# <col style="width: 50%" />
# <col style="width: 50%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><p>In [3]:</p>
# <p>In [4]:</p></th>
# <th><table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p><strong>def</strong> test():<br />
# a<strong>=</strong> int(input("Enter first number:- "))<br />
# b<strong>=</strong> int(input("Enter second number:- "))<br />
# summation <strong>=</strong> a<strong>+</strong>b<br />
# multiplication <strong>=</strong> a<strong>*</strong>b<br />
# print(f"The summation is {summation} and multiplication is
# {multiplication} of the given numbers {a} and {b}")</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
# <table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>test()</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
#
# > Enter first number:- 3
# > Enter second number:- 4
# > The summation is 7 and multiplication is 12 of the given numbers 3 and
# > 4
#
# <table>
# <colgroup>
# <col style="width: 50%" />
# <col style="width: 50%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>In [11]:</p>
# </blockquote></th>
# <th><table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p><em># USING LAMBDA FUNCTION</em><br />
# a<strong>=</strong> int(input("Enter first number:- "))<br />
# b<strong>=</strong> int(input("Enter second number:- "))<br />
# add <strong>=lambda</strong> a,b: a<strong>+</strong>b<br />
# mul <strong>=lambda</strong> a,b: a<strong>*</strong>b<br />
# addition <strong>=</strong> add(a,b)<br />
# multiply <strong>=</strong> mul(a,b)<br />
# print("summation:- ",addition)<br />
# print("multiplication:- ",multiply)</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
#
# > Enter first number:- 4
# > Enter second number:- 5
# > summation:- 9
# > multiplication:- 20
# >
# > QUES 3:- WRITE A FUNCTION THAT TAKES A VARIABLE AND RETURNS ITS
# > FACTORIAL
#
# <table>
# <colgroup>
# <col style="width: 50%" />
# <col style="width: 50%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>In [17]:</p>
# </blockquote></th>
# <th><table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p><strong>def</strong> factorial(n):<br />
# <strong>if</strong> n <strong>==</strong>0<strong>or</strong> n
# <strong>==</strong>1:<br />
# <strong>return</strong>1<br />
# <strong>else</strong>:<br />
# <strong>return</strong> n <strong>*</strong> factorial(n
# <strong>-</strong>1)<em># factorial of 5--&gt; 1*2= 2*3= 6*4 =24*5
# =120</em> num <strong>=</strong> int(input("Enter a number: "))<br />
# result <strong>=</strong> factorial(num)<br />
# print(f"The factorial of {num} is {result}")</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
#
# > Enter a number: 5
# > The factorial of 5 is 120
# >
# > QUES 4:- DEVELOP A SCRIPT WHOSE ITEMS ARE SQUARES OF THE ORIGINAL LIST
#
# <table>
# <colgroup>
# <col style="width: 50%" />
# <col style="width: 50%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>In [17]:</p>
# <p>In [18]:</p>
# </blockquote></th>
# <th><table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p><strong>def</strong> sq():<br />
# s<strong>=</strong>[]<br />
# a<strong>=</strong> input("enter a list seperated by commas:-
# ")<strong>.</strong>split(",")<br />
# <strong>for</strong> i <strong>in</strong> a:<br />
# i<strong>=</strong> int(i)<br />
# s<strong>.</strong>append(i<strong>**</strong>2)<br />
# print("Orignal list is :- ",a)<br />
# print("Squared list is:- ",s)</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
# <table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>sq()</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
#
# > enter a list seperated by commas:- 1,2,3,4
# > Orignal list is :- \['1', '2', '3', '4'\]
# > Squared list is:- \[1, 4, 9, 16\]
# >
# > QUES 5:- WRITE A FUNCTION THAT SQUARES A VARIABLE AND THEN TEST THE
# > FUNCTION USING A LIST OF INTEGER NUMBERS RANGING FROM -20 to 20
#
# <table>
# <colgroup>
# <col style="width: 50%" />
# <col style="width: 50%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>In [24]:</p>
# <p>In [25]:</p>
# </blockquote></th>
# <th><table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p><strong>def</strong> square(a):<br />
# <strong>for</strong> i <strong>in</strong> a:<br />
# i<strong>=</strong> int(i)<br />
# print(i<strong>**</strong>2)<br />
# b<strong>=</strong> list(range(<strong>-</strong>20,21))</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
# <table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>square(b)</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
#
# > 400
# > 361
# > 324
# > 289
# > 256
# > 225
# > 196
# > 169
# > 144
# > 121
# > 100
# > 81
# > 64
# > 49
# > 36
# > 25
# > 16
# > 9
# > 4
# > 1
# > 0
# > 1
# > 4
# > 9
# > 16
# > 25
# > 36
# > 49
# > 64
# > 81
# > 100
# > 121
# > 144
# > 169
# > 196
# > 225
# > 256
# > 289
# > 324
# > 361
# > 400
# >
# > QUES 6:- WRITE 3 FUNCTIONS THAT TAKE THE RADIUS OF A CIRCLE AND RETURN
# > THE DIAMETER, AREA AND CIRCUMFERENCE, TEST THE FUNCTION USING AN INPUT
# > FROM A USER
#
# <table>
# <colgroup>
# <col style="width: 50%" />
# <col style="width: 50%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><p>In [2]:</p>
# <p>In [5]:</p></th>
# <th><table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p><strong>def</strong> circle():<br />
# r<strong>=</strong> int(input("Enter radius:- "))<br />
# print("diameter = ",2<strong>*</strong>r)<br />
# print("circumference =
# ",2<strong>*</strong>3.14<strong>*</strong>r)<br />
# print("area = ",3.14<strong>*</strong>r<strong>**</strong>2)</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
# <table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>circle()</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
#
# > Enter radius:- 5
# > diameter = 10
# > circumference = 31.400000000000002
# > area = 78.5
# >
# > QUES 7:- WRITE A CODE THAT TAKES A RANGE FROM A USER (UPPER AND LOWER
# > BOUND) AND RETURNS A LIST OF POSITIVE AND EVEN NUMBERS ONLY
#
# <table>
# <colgroup>
# <col style="width: 50%" />
# <col style="width: 50%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><p>In [7]:</p>
# <p>In [9]:</p></th>
# <th><table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p><strong>def</strong> positive_even():<br />
# a<strong>=</strong> int(input("Enter minimum value of range:- "))<br />
# b<strong>=</strong> int(input("Enter maximum value of range:- "))<br />
# p <strong>=</strong>[]<br />
# <strong>for</strong> i <strong>in</strong>
# range(a,b<strong>+</strong>1):<br />
# <strong>if</strong> i<strong>%2</strong>==0 and i&gt;0 :<br />
# p<strong>.</strong>append(i)<br />
# print("IN THE RANGE BETWEEN {} TO {} :-
# "<strong>.</strong>format(a,b))<br />
# print("POSITIVE EVEN NUMBERS :- ",p)</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
# <table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>positive_even()</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
#
# > Enter minimum value of range:- -10
# > Enter maximum value of range:- 10
# > IN THE RANGE BETWEEN -10 TO 10 :-
# > POSITIVE EVEN NUMBERS :- \[2, 4, 6, 8, 10\]
# >
# > QUES 8:- USING FILTER AND LAMBDA EXPRESSION, WRITE A CODE THAT TAKES A
# > LIST OF NUMBERS BELOW AND RETURNS EVEN NUMBERS ONLY
#
# <table>
# <colgroup>
# <col style="width: 50%" />
# <col style="width: 50%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>In [17]:</p>
# <p>In [34]:</p>
# <p>Out[34]:</p>
# </blockquote></th>
# <th><table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>a<strong>=</strong>[2,4,67,5,14,6,43,10,3]</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
# <table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>b<strong>=</strong> list(filter(<strong>lambda</strong> x:
# x<strong>%2</strong>==0 , a))<br />
# b</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
# <blockquote>
# <p>[2, 4, 14, 6, 10]</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
#
# > QUES 9:- WRITE A FUNCTION THAT TAKES TWO NUMPY MATRICES AND RETURN THE
# > ADDITION, SUBTRACTION, TRANSPOSE, PRODUCT, DOT PRODUCT
#
# <table>
# <colgroup>
# <col style="width: 50%" />
# <col style="width: 50%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>In [35]:</p>
# </blockquote></th>
# <th><table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p><strong>import</strong> numpy <strong>as</strong> np<br />
# <strong>def</strong> matrix_operations(matrix1, matrix2):<br />
# <em># Addition</em><br />
# addition_result <strong>=</strong> matrix1 <strong>+</strong>
# matrix2<br />
# <em># Subtraction</em><br />
# subtraction_result <strong>=</strong> matrix1 <strong>-</strong>
# matrix2<br />
# <em># Transpose</em><br />
# transpose_matrix1 <strong>=</strong>
# np<strong>.</strong>transpose(matrix1)<br />
# transpose_matrix2 <strong>=</strong>
# np<strong>.</strong>transpose(matrix2)<br />
# <em># Element-wise product</em><br />
# elementwise_product <strong>=</strong> matrix1 <strong>*</strong>
# matrix2<br />
# <em># Dot product</em><br />
# dot_product <strong>=</strong> np<strong>.</strong>dot(matrix1,
# matrix2)<br />
# <strong>return</strong> addition_result, subtraction_result,
# transpose_matrix1, transpose_matrix2, elementwise_product, dot_product
# <em># Example usage</em><br />
# matrix1 <strong>=</strong>
# np<strong>.</strong>array([[1,2],[3,4]])<br />
# matrix2 <strong>=</strong>
# np<strong>.</strong>array([[5,6],[7,8]])<br />
# add_result, sub_result, trans1, trans2, elem_prod, dot_prod
# <strong>=</strong> matrix_operations(matrix1, matrix2)<br />
# print("Addition Result:")<br />
# print(add_result)<br />
# print("\nSubtraction Result:")<br />
# print(sub_result)<br />
# print("\nTranspose of Matrix 1:")<br />
# print(trans1)<br />
# print("\nTranspose of Matrix 2:")<br />
# print(trans2)<br />
# print("\nElement-wise Product:")<br />
# print(elem_prod)<br />
# print("\nDot Product:")<br />
# print(dot_prod)</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
#
# > Addition Result:
# > \[\[ 6 8\]
# > \[10 12\]\]
# >
# > Subtraction Result:
# > \[\[-4 -4\]
# > \[-4 -4\]\]
# >
# > Transpose of Matrix 1:
# > \[\[1 3\]
# > \[2 4\]\]
# >
# > Transpose of Matrix 2:
# > \[\[5 7\]
# > \[6 8\]\]
# >
# > Element-wise Product:
# > \[\[ 5 12\]
# > \[21 32\]\]
# >
# > Dot Product:
# > \[\[19 22\]
# > \[43 50\]\]
# >
# > QUES 10:- WRITE A FUNCTION THAT TAKES TWO VALUES FROM A USER AND SUM
# > THEM UP. IF NO VALUES ARE PROVIDED, ASSUME DEFAULT VALUES OF 3 AND 5
#
# <table>
# <colgroup>
# <col style="width: 50%" />
# <col style="width: 50%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>In [44]:</p>
# <p>In [46]:</p>
# </blockquote></th>
# <th><table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p><strong>def</strong> add():<br />
# a<strong>=</strong> input("Enter first number:- ")<br />
# b<strong>=</strong> input("Enter second number:- ")<br />
# <strong>if</strong> a<strong>==</strong>" ":<br />
# a<strong>=</strong>3<br />
# <strong>else</strong>:<br />
# a<strong>=</strong>float(a)<br />
# <strong>if</strong> b<strong>==</strong>" ":<br />
# b<strong>=</strong>5<br />
# <strong>else</strong>:<br />
# b<strong>=</strong>float(b)<br />
# <strong>return</strong>(f"sum of {a} and {b} is
# {a<strong>+</strong>b}")</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
# <table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>add()</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
#
# > Enter first number:- 4
# > Enter second number:- 5
#
# <table>
# <colgroup>
# <col style="width: 50%" />
# <col style="width: 50%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>Out[46]:</p>
# <p>In [47]:</p>
# </blockquote></th>
# <th><blockquote>
# <p>'sum of 4.0 and 5.0 is 9.0'</p>
# </blockquote>
# <table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>add()</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
#
# > Enter first number:-
# > Enter second number:-
# >
# > Out\[47\]: 'sum of 3 and 5 is 8'
# >
# > QUES 11:- WRITE A SCRIPT THAT WILL PROMPT A USER FOR A RANGE (MIN/MAX
# > VALUE) AND RETURNS NUMBERS THAT ARE DIVISIBLE BY 4 BUT ARE NOT
# > MULTIPLES OF 3
#
# <table>
# <colgroup>
# <col style="width: 50%" />
# <col style="width: 50%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>In [48]:</p>
# <p>In [49]:</p>
# </blockquote></th>
# <th><table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p><strong>def</strong> num():<br />
# a<strong>=</strong> int(input("Enter minimum value of range:- "))<br />
# b<strong>=</strong> int(input("Enter maximum value of range:- "))<br />
# <strong>for</strong> i <strong>in</strong>
# range(a,b<strong>+</strong>1):<br />
# <strong>if</strong> i<strong>%4</strong>==0 and i%3!=0:<br />
# print(i)</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
# <table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>num()</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
#
# > Enter minimum value of range:- 10
# > Enter maximum value of range:- 30
# > 16
# > 20
# > 28
# >
# > QUES 12:- DEFINE AN ENGLISH TO FRENCH TRANSLATOR FUNCTION THAT TAKES
# > AN INPUT FROM A USER AND RETURNS THE TRANSLATION, USE ANY 5 KNOWN
# > WORDS
#
# <table>
# <colgroup>
# <col style="width: 50%" />
# <col style="width: 50%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>In [50]:</p>
# <p>In [57]:</p>
# <p>In [59]:</p>
# </blockquote></th>
# <th><table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>eng_to_french <strong>=</strong>{"friend":"ami",<br />
# "car":"voiture",<br />
# "sun":"soleil",<br />
# "water":"eau",<br />
# "house":"maison"}</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
# <table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p><strong>def</strong> french():<br />
# a <strong>=</strong> input("Enter english word to translate in french:-
# ")<br />
# <strong>return</strong> eng_to_french[a]</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
# <table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>french()</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
#
# > Enter english word to translate in french:- sun
# >
# > Out\[59\]: 'soleil'
