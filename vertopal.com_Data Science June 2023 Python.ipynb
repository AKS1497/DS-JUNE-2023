# %% [markdown]
# #1. Write a program which contains one function named as Fun(). That
# function should display “Hello from Fun” on console.
#
# Answer: def fun(): #def is a keyword. It use to define a function.
#
# print("hello from fun")
#
# fun()
#
# \# fun is a function. When u call fun() it display hello from fun.
#
# \# 2.Write a program which contains one function named as ChkNum ()
# which accept one parameter as number.If number is even then it should
# display “Even number” otherwise display “Odd number” on console.
#
# Answer: def ChkNum(Number): #ChkNum is a function. Number is element.
#
# if (Number%2 ==0): \# Logic-if 2 is divisible by any number is even or 2
# is
#
# \# not divide by 2is even and number value is 0==0.
#
# print("Number is even")
#
# else:
#
# print("Number is odd")
#
# Num=(int(input("Enter the number"))) \# there define a function create a
# prompt to user
#
# #by using input().convert input to integer use int.
#
# ChkNum(x) \# there call chknum for output
#
# #3. Write a program which contains one function named as Add () which
# accepts two numbers from user and return addition of that two numbers.
#
# Answer: def Add(A,B)
#
# return A+B #return is statement is used to value back to the caller
# function.
#
# A=(int(input("Enter A")))
#
# B=(int(input("Enter B")))
#
# print((A+B))
#
# #4. Write a program which display 5 times Marvelous on screen.
#
# Answer: def printname(): #for is a syntax for loop, i represent the
# individual item example in this code I
#
# For I in range(5) #represent marvellous.Range is function its use for
# item sequence and
#
# #give item specific range 0 to 5
#
# print("MARVELLOUS")
#
# printname()
#
# #5. Write a program which display 10 to 1 on screen.
#
# Answer: for I in range(10 , 0 , -1)
#
# Print(i)
#
# #6. Write a program which accept number from user and check whether that
# number is positive or negative or zero.
#
# Answer: def checknumber(x):
#
# if x\>0:
#
# print("Number is positive")
#
# elif x\<0: #elif is keyword stands fo else and if.
#
# print("Number is negative")
#
# elif x==0:
#
# print("Number is zero")
#
# x=(int(input("Enter the number")))
#
# checknumber(x)
#
# 7\. Write a program which contains one function that accept one number
# from user and returns true if number is divisible by 5 otherwise return
# false.
#
# Answer: def Number(x):
#
# if (x%5 ==0):
#
# print("Number is divisible by 5")
#
# else:
#
# print("Number is not divisible by 5")
#
# x=(int(input("Enter the number")))
#
# Number(x)
#
# #8. Write a program which accept number from user and print that number
# of “\*” on screen.
#
# ANSWER:
#
# def printPattern(x):
#
# for i in range(x):
#
# print("\*")
#
# x = int(input("Enter the number: "))
#
# printPattern(x)
#
# #9. Write a program which display first 10 even numbers on screen.
#
# ANSWER:-\> print(\[x for x in range(20) if x % 2 == 0\]\[:10\])
#
# #10. Write a program which accept name from user and display length of
# its name.
#
# ANSWER:
#
# def length(name):
#
# length = len(name)
#
# print("Length of the name:", length)
#
# name = input("Enter a name: ")
#
# length(name)
